# %%
from IPython import display
import numpy as np
import matplotlib.pyplot as plt
import pickle
from scipy import interpolate

# %%
with open('../data/s1_cut_forces.pkl', 'rb') as f:
        student_1 = pickle.load(f,encoding="bytes") # remove "encoding" parameter if in Python 2 kernel

with open('../data/s11_cut_forces.pkl', 'rb') as f:
        student_11 = pickle.load(f,encoding="bytes") # remove "encoding" parameter if in Python 2 kernel

# %%
from scipy.io import savemat

def savematfiles(reference, reference_us, profile, profile_us, student, cut, num):
    
    student = str(student).zfill(2)
    cut = str(cut).zfill(2)
    
    mdic = {'reference': reference_us, 'actual': profile_us,'Ts': 0.001}
    savemat('./data/transient/1kHz/student'+str(student)+'cut'+str(cut)+'_'+str(num)+'_1kHz.mat', mdic)

    mdic = {'reference': reference, 'actual': profile,'Ts': 0.0333}
    savemat('./data/transient/30Hz/student'+str(student)+'cut'+str(cut)+'_'+str(num)+'_30Hz.mat', mdic)
    
def upsample(reference,profile):
    
    # Upsample from 30Hz to 1kHz, (for dt=0.001 step)
    xnew = np.arange(0,reference.shape[0]-1,1/33.33)
    reference_inter = interpolate.interp1d(x=np.arange(reference.shape[0]),y=reference)
    reference_us = reference_inter(xnew)
    
    xnew = np.arange(0,profile.shape[0]-1,1/33.33)
    profile_inter = interpolate.interp1d(x=np.arange(profile.shape[0]),y=profile)
    profile_us = profile_inter(xnew)
    
    return reference_us, profile_us

# %% [markdown]
# # Student 11 (reference)

# %%
for i in range(12):
    plt.plot(student_11[i])
plt.show()

# %%
# Here we slice the ROI of each force profile
cut = 10
startx = [40,25,60,33,91,45,52,25,50,20,66,18]
endx = [260,270,273,192,235,215,184,172,238,163,191,170]

plt.plot(student_11[cut])
plt.axvline(x=startx[cut],ls='--')
plt.axvline(x=endx[cut],ls='--')
plt.show()

# %%
for cut in range(12):
    plt.plot(student_11[cut][startx[cut]:endx[cut]])
plt.show()

# %%
# Choose reference force profile 
reference = np.copy(student_11[8][startx[8]:endx[8]])
reference[np.where(reference < 0)[0]] = 0
reference = reference[max(np.where(reference == 0)[0]):]
plt.plot(reference); plt.show()

# Upsample from 30Hz to 1kHz, (for dt=0.001 step)
xnew = np.arange(0,reference.shape[0]-1,1/33.33)
reference_inter = interpolate.interp1d(x=np.arange(reference.shape[0]),y=reference)
reference_us = reference_inter(xnew)
plt.plot(reference_us); plt.show();

# %% [markdown]
# # Student 1

# %%
for i in range(12):
    plt.plot(student_1[i])
plt.show()

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 0
num = 0
startx = 20

plt.plot(student_1[cut][startx:startx+reference[:].shape[0]])
plt.plot(reference[:],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference,profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 1
num = 0
startx = 12
endx = 132

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 1
num = 1
startx = 175

plt.plot(student_1[cut][startx:startx+reference.shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference.shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference,profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 2
startx = 12

plt.plot(student_1[cut][startx:startx+reference[:].shape[0]])
plt.plot(reference[:],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference,profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 3
startx = 28

plt.plot(student_1[cut][startx:startx+reference[:].shape[0]])
plt.plot(reference[:],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference,profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 4
num = 0
startx = 36
endx = 44

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 4
num = 1
startx = 93
# endx = 180

plt.plot(student_1[cut][startx:startx+reference.shape[0]])
plt.plot(reference,'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference.shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference,profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 5
num = 0
startx = 0
endx = 95

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 5
num = 1
startx = 113
endx = 123

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 5
num = 2
startx = 252
endx = 118

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 6
num = 0
startx = 44

plt.plot(student_1[cut][startx:startx+reference[:].shape[0]])
plt.plot(reference[:],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference,profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 7
num = 0
startx = 0
endx = 43

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 7
num = 1
startx = 58

plt.plot(student_1[cut][startx:startx+reference[:].shape[0]])
plt.plot(reference[:],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 8
num = 0
startx = 28
endx = 87

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 8
num = 1
startx = 124
endx = 128

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 9
num = 0
startx = 60
endx = 180

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 10
num = 0
startx = 17
endx = 40

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 10
num = 1
startx = 67
endx = 180

plt.plot(student_1[cut][startx:startx+reference[:].shape[0]])
plt.plot(reference[:],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 11
num = 0
startx = 23
endx = 54

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %%
# Here we slice the ROI of each force profile
student = 1
cut = 11
num = 1
startx = 100
endx = 175

plt.plot(student_1[cut][startx:startx+reference[:endx].shape[0]])
plt.plot(reference[:endx],'--',label='reference') 
plt.legend(); plt.grid(); plt.title('Full length'); plt.show()

plt.plot(student_1[cut][startx:startx+reference[:20].shape[0]])
plt.plot(reference[:20],'--',label='reference'); 
plt.legend(); plt.grid(); plt.title('Transient region'); plt.show()

profile = np.copy(student_1[cut][startx:startx+reference[:endx].shape[0]])
profile[np.where(profile < 0)[0]] = 0
profile[0] = 0

plt.plot(profile[:20]); plt.plot(reference[:20],'--',label='reference')
plt.legend(); plt.grid(); plt.title('Zero-corrected'); plt.show()

# Upsample
reference_us, profile_us = upsample(reference[:endx],profile)
plt.plot(profile_us)
plt.plot(reference_us,'--')

# Save
savematfiles(reference, reference_us, profile, profile_us, student, cut, num)

# %% [markdown]
# # Student 1. Summary

# %%
import scipy.io
# mat = scipy.io.loadmat('file.mat')

student1_files = ['student01cut00_0_30Hz.mat','student01cut05_0_30Hz.mat','student01cut08_1_30Hz.mat',
'student01cut01_0_30Hz.mat','student01cut05_1_30Hz.mat','student01cut09_0_30Hz.mat',
'student01cut01_1_30Hz.mat','student01cut05_2_30Hz.mat','student01cut10_0_30Hz.mat',
'student01cut02_1_30Hz.mat','student01cut06_0_30Hz.mat','student01cut10_1_30Hz.mat',
'student01cut03_1_30Hz.mat','student01cut07_0_30Hz.mat','student01cut11_0_30Hz.mat',
'student01cut04_0_30Hz.mat','student01cut07_1_30Hz.mat','student01cut11_1_30Hz.mat',
'student01cut04_1_30Hz.mat','student01cut08_0_30Hz.mat']

cutting_profiles = []

for i in range(len(student1_files)):
    cutting_profiles.append(scipy.io.loadmat('./data/transient/30Hz/'+student1_files[i])['actual'][0])
    
for i in range(len(cutting_profiles)):
    plt.plot(cutting_profiles[i])
    
print(len(cutting_profiles))
# Out:
# 20
