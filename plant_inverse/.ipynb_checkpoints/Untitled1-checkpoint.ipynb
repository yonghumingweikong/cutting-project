# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from numpy import genfromtxt
from numpy.linalg import lstsq

# %%
ramp = lambda u: np.maximum( u, 0 )
step = lambda u: ( u > 0 ).astype(float)

def SegmentedLinearReg( X, Y, breakpoints ):
    nIterationMax = 10

    breakpoints = np.sort( np.array(breakpoints) )

    dt = np.min( np.diff(X) )
    ones = np.ones_like(X)

    for i in range( nIterationMax ):
        # Linear regression:  solve A*p = Y
        Rk = [ramp( X - xk ) for xk in breakpoints ]
        Sk = [step( X - xk ) for xk in breakpoints ]
        A = np.array([ ones, X ] + Rk + Sk )
        p =  lstsq(A.transpose(), Y, rcond=None)[0] 

        # Parameters identification:
        a, b = p[0:2]
        ck = p[ 2:2+len(breakpoints) ]
        dk = p[ 2+len(breakpoints): ]

        # Estimation of the next break-points:
        newBreakpoints = breakpoints - dk/ck 

        # Stop condition
        if np.max(np.abs(newBreakpoints - breakpoints)) < dt/5:
            break

        breakpoints = newBreakpoints
    else:
        print( 'maximum iteration reached' )

    # Compute the final segmented fit:
    Xsolution = np.insert( np.append( breakpoints, max(X) ), 0, min(X) )
    ones =  np.ones_like(Xsolution) 
    Rk = [ c*ramp( Xsolution - x0 ) for x0, c in zip(breakpoints, ck) ]

    Ysolution = a*ones + b*Xsolution + np.sum( Rk, axis=0 )

    return Xsolution, Ysolution

def get_strain_reference(strain,initialBreakpoints):

    X = np.arange(0,180)
    Y = strain
    plt.plot( X, Y, '--' );

#     initialBreakpoints = [130,160]
    px, py = SegmentedLinearReg( X, Y, initialBreakpoints )
    plt.plot(px, py, '-ro' )
    plt.show()
    
    for i in range(px.shape[0]-1):

        plt.figure(figsize=(15,5))

        plt.subplot(1,2,1)
        plt.plot(X[int(px[i]):int(px[i+1])],Y[int(px[i]):int(px[i+1])],label='actual')
        plt.plot(px[i:i+2],py[i:i+2])
        plt.title('Strain, linear fit')
        plt.legend()

        slope = np.diff(py[i:i+2])/np.diff(px[i:i+2])
        plt.subplot(1,2,2)
        plt.plot(X[int(px[i]):int(px[i+1])],Y[int(px[i]):int(px[i+1])] - (np.arange(0,int(px[i+1])-int(px[i]))*slope + py[i]))
        plt.grid()
        plt.title('Strain, residuals')

# %%
student_1_strain_ref = np.zeros([12,179])
student_1_strain_rate_ref = np.zeros([12,179])

# %%
student_1_force = np.zeros([12,180])
student_1_strain = np.zeros([12,180])

for i in range(12):
    student_1_force[i,:] = genfromtxt('./data/student_1_force_'+str(i+1)+'.csv', delimiter=',')
    student_1_strain[i,:] = genfromtxt('./data/student_1_strain_'+str(i+1)+'.csv', delimiter=',')

for i in range(12):
    plt.plot(student_1_force[i,:])
plt.show()
    
for i in range(12):
    plt.plot(student_1_strain[i,:])
plt.show()
    

# plt.plot(force); plt.grid(); plt.title('Actual force'); plt.show()
# plt.plot(strain); plt.grid(); plt.title('Continuous strain (inferred by plant inversion)'); plt.show()

# %%
cut = 0
get_strain_reference(student_1_strain[cut,:],[0])

# %%
cut = 1
get_strain_reference(student_1_strain[cut,:],[125,160])
# Out:
# maximum iteration reached

# %%
cut = 2
get_strain_reference(student_1_strain[cut,:],[0])

# %%
cut = 3
get_strain_reference(student_1_strain[cut,:],[0])

# %%
cut = 4
get_strain_reference(student_1_strain[cut,:],[30,55])

# %%
cut = 5
get_strain_reference(student_1_strain[cut,:],[90,120])

# %%
cut = 6
get_strain_reference(student_1_strain[cut,:],[10])

# %%
cut = 7
get_strain_reference(student_1_strain[cut,:],[40,60])

# %%
cut = 8
get_strain_reference(student_1_strain[cut,:],[40,100,125])

# %%
cut = 9
get_strain_reference(student_1_strain[cut,:],[30,65,130])

# %%
cut = 10
get_strain_reference(student_1_strain[cut,:],[30,60,100])

# %%
cut = 11
get_strain_reference(student_1_strain[cut,:],[50,80,125])
# Out:
# maximum iteration reached

# %%
x = electrocardiogram()[17000:18000]
peaks, properties = find_peaks(x, prominence=1, width=20)
properties["prominences"], properties["widths"]

plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.vlines(x=peaks, ymin=x[peaks] - properties["prominences"],
           ymax = x[peaks], color = "C1")
plt.hlines(y=properties["width_heights"], xmin=properties["left_ips"],
           xmax=properties["right_ips"], color = "C1")
plt.show()

# %%
cut = 8
plt.plot(student_1_strain[cut,:]); plt.show()
plt.plot(np.diff(student_1_strain[cut,:]))

# %%
cut = 4
plt.plot(student_1_strain[cut,:]); plt.show()

x = -np.diff(student_1_strain[cut,:])

peaks, _ = find_peaks(x, distance=180)
np.diff(peaks)

plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.show()

# %%
plt.plot(student_1_strain[cut,:])
plt.plot(peaks-2,student_1_strain[cut,peaks-2],'x'); plt.show()

# %%
X = np.arange(0,180)
Y = student_1_strain[cut,:]
plt.plot( X, Y, '--' );

#     initialBreakpoints = [130,160]
px, py = SegmentedLinearReg( X, Y )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-320-a91c68b8ca04> in <module>()
#       4
#       5 #     initialBreakpoints = [130,160]
# ----> 6 px, py = SegmentedLinearReg( X, Y )
#
# TypeError: SegmentedLinearReg() missing 1 required positional argument: 'breakpoints'
